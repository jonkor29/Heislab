# %% [markdown]
# ML Project Part 3: Classification

# %%
#Imports
import numpy as np
import matplotlib.pyplot as plt
import ipywidgets as widgets
from IPython.display import display
import os

import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score

# %%
if 'google.colab' in str(get_ipython()):
  print('Running on CoLab')
  running_on_colab = True
else:
  print('Not running on CoLab')
  running_on_colab = False
# Out:
# Running on CoLab

# %%
if running_on_colab:
  from google.colab import drive
  drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
if running_on_colab:
  FILES_PATH = "drive/MyDrive/ml_project_data/part3/"
else:
  FILES_PATH = None #put the right path here i guess

# %%
# Importing data, defining constants
X_handout = np.load(os.path.join(FILES_PATH, "Xtrain_Classification1.npy"))
Y_handout = np.load(os.path.join(FILES_PATH, "ytrain_Classification1.npy"))
X_test_delivery = np.load(os.path.join(FILES_PATH, "Xtest_Classification1.npy"))
NUM_HANDOUT_SAMPLES = X_handout.shape[0]
NUM_FEATURES = X_handout.shape[1]
IMAGE_WIDTH = IMAGE_HEIGHT = 28

print(f"X_handout shape: {X_handout.shape}")
print(f"Y_handout shape: {Y_handout.shape}")
print(f"X_test_delivery shape: {X_test_delivery.shape}")

print(f"Number of handout examples: {NUM_HANDOUT_SAMPLES}")
print(f"Number of features per sample: {NUM_FEATURES}")

print(f"Number of melanoma:{np.count_nonzero(Y_handout == 1)}")
print(f"Number of nevu:{np.count_nonzero(Y_handout == 0)}")

print(f"Image Size: {IMAGE_WIDTH}x{IMAGE_HEIGHT}")
# Out:
# X_handout shape: (6254, 2352)
# Y_handout shape: (6254,)
# X_test_delivery shape: (1764, 2352)
# Number of handout examples: 6254
# Number of features per sample: 2352
# Number of melanoma:896
# Number of nevu:5358
# Image Size: 28x28

# %%
# Displaying the images
def show_image(index):
    rgb_image = np.reshape(X_handout[index], (28, 28, 3))
    plt.imshow(rgb_image)
    plt.axis("off")
    plt.show()

    class_label_widget.value = f"Class (0 or 1): {Y_handout[index]}"

class_label_widget = widgets.Label(value=f"Class (0 or 1): {-1}")
image_widget = widgets.interactive(
    show_image, index=widgets.IntSlider(min=0, max=len(X_handout) - 1, step=1, value=0)
)
display(image_widget, class_label_widget)
# Out:
# interactive(children=(IntSlider(value=0, description='index', max=6253), Output()), _dom_classes=('widget-inte…
# Label(value='Class (0 or 1): 1.0')

# %%
def upsample(X, Y, class_id, upsample_factor, shuffle=False):
  """
    Upsamples by creating copies of samples belonging to class_id in X

    Returns:
        Samples X with lables Y
    """
  X_to_upsample = X[Y == class_id]
  X_upsampled = np.repeat(X_to_upsample, upsample_factor, axis=0)
  X_new = np.concatenate((X_upsampled, X), axis=0)
  Y_new = np.concatenate((np.ones(X_upsampled.shape[0])*class_id, Y), axis=0)
  if shuffle:
    shuffle_mask = np.random.permutation(X_new.shape[0])
    return X_new[shuffle_mask], Y_new[shuffle_mask]
  else:
    return X_new, Y_new

def downsample(X, Y, class_id, shuffle=False):
    """
    Downsamples by deleting samples belonging to class_id in X, untill the dataset is balanced
    Returns:
        Samples X with lables Y
    """
    if class_id == 1:
      other_class_label = 0
    elif class_id == 0:
      other_class_label = 1

    X_to_downsample = X[Y == class_id]
    X_downsampled = X_to_downsample[0:len(X[Y != class_id])]
    assert(X_downsampled.shape == X[Y != class_id].shape)
    X_new = np.concatenate((X_downsampled, X[Y != class_id]), axis=0)
    Y_new = np.concatenate((np.ones(X_downsampled.shape[0])*class_id, np.ones(X[Y != class_id].shape[0])*other_class_label), axis=0)
    if shuffle:
      shuffle_mask = np.random.permutation(X_new.shape[0])
      return X_new[shuffle_mask], Y_new[shuffle_mask]
    else:
      return X_new, Y_new

# %%
#X_handout_rescaled = np.array([rgb_val/255 for rgb_val in X_handout])
#X_handout_reshaped = np.array([np.reshape(pic, (28, 28, 3)) for pic in X_handout_rescaled])
X_handout_rescaled = X_handout/255
X_handout_reshaped = np.reshape(X_handout_rescaled, newshape=(NUM_HANDOUT_SAMPLES, 28, 28, 3))

#upsampling
print("X_handout_reshaped.shape: ", X_handout_reshaped.shape)
print("Y_handout.shape: ", Y_handout.shape)

#note: the upsampling should happen in a way that does not leave duplicates in train and test set
#upsample after train_test_split and then shuffle
UPSAMPLE_FACTOR = 5
# ------ old upsample code -----
"""
X_handout_melanoma = X_handout_reshaped[Y_handout == 1]
X_handout_melanoma_upscaled = np.repeat(X_handout_melanoma, UPSAMPLE_FACTOR, axis=0)
X_handout_upscaled = np.concatenate((X_handout_melanoma_upscaled, X_handout_reshaped), axis = 0)
Y_handout_upscaled = np.concatenate((np.ones(X_handout_melanoma_upscaled.shape[0]), Y_handout), axis = 0)
print("X_handout_upscaled.shape: ", X_handout_upscaled.shape)
print("Y_handout_upscaled.shape: ", Y_handout_upscaled.shape)
"""
# ----- old upsample code -----

X_train, X_test, y_train, y_test = train_test_split(X_handout_reshaped, Y_handout, test_size=0.2, random_state=42)

print("Before upsampling:")
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)

#Downsample
X_train, y_train = downsample(X_train, y_train, class_id=0, shuffle=True)
X_test, y_test = downsample(X_test, y_test, class_id=0, shuffle=True)

#Upsample
#X_train, y_train = upsample(X_train, y_train, class_id=1, upsample_factor=UPSAMPLE_FACTOR, shuffle=True)
#X_test, y_test = upsample(X_test, y_test, class_id=1, upsample_factor=UPSAMPLE_FACTOR, shuffle=True)

print("After upsampling:")
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)
print(f"Number of melanoma in train set:{np.count_nonzero(y_train == 1)}, test set: {np.count_nonzero(y_test == 1)}")
print(f"Number of nevu in train set:{np.count_nonzero(y_train == 0)}, test set: {np.count_nonzero(y_test == 0)}")
# Out:
# X_handout_reshaped.shape:  (6254, 28, 28, 3)
# Y_handout.shape:  (6254,)
# Before upsampling:
# X_train shape: (5003, 28, 28, 3)
# y_train shape: (5003,)
# X_test shape: (1251, 28, 28, 3)
# y_test shape: (1251,)
# After upsampling:
# X_train shape: (1438, 28, 28, 3)
# y_train shape: (1438,)
# X_test shape: (354, 28, 28, 3)
# y_test shape: (354,)
# Number of melanoma in train set:719, test set: 177
# Number of nevu in train set:719, test set: 177

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(IMAGE_HEIGHT, IMAGE_WIDTH, 3)),
    tf.keras.layers.MaxPooling2D((2, 2)),
    #tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    #tf.keras.layers.MaxPooling2D((2, 2)),
    #tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(100, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')  # Binary classification, so use sigmoid activation
])


model.compile(optimizer='adam',
              loss='binary_crossentropy',  # Binary cross-entropy for binary classification
              metrics=[tf.keras.metrics.Precision(name = 'precision'),
                       tf.keras.metrics.Recall(name = 'recall'),
                       'accuracy'])

# %%
history = model.fit(X_train, y_train, epochs=20, validation_data=(X_test, y_test), batch_size = 50)
# Out:
# Epoch 1/200
# 3/3 [==============================] - 0s 124ms/step - loss: 0.0561 - precision: 0.9889 - recall: 0.9889 - accuracy: 0.9889 - val_loss: 0.7019 - val_precision: 0.7632 - val_recall: 0.8192 - val_accuracy: 0.7825
# Epoch 2/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0523 - precision: 0.9930 - recall: 0.9903 - accuracy: 0.9917 - val_loss: 0.7013 - val_precision: 0.7526 - val_recall: 0.8079 - val_accuracy: 0.7712
# Epoch 3/200
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0529 - precision: 0.9862 - recall: 0.9917 - accuracy: 0.9889 - val_loss: 0.6782 - val_precision: 0.7604 - val_recall: 0.8249 - val_accuracy: 0.7825
# Epoch 4/200
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0548 - precision: 0.9890 - recall: 0.9972 - accuracy: 0.9930 - val_loss: 0.6787 - val_precision: 0.7526 - val_recall: 0.8249 - val_accuracy: 0.7768
# Epoch 5/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0488 - precision: 0.9917 - recall: 0.9944 - accuracy: 0.9930 - val_loss: 0.6907 - val_precision: 0.7513 - val_recall: 0.8362 - val_accuracy: 0.7797
# Epoch 6/200
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0524 - precision: 0.9903 - recall: 0.9903 - accuracy: 0.9903 - val_loss: 0.6832 - val_precision: 0.7632 - val_recall: 0.8192 - val_accuracy: 0.7825
# Epoch 7/200
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0530 - precision: 0.9916 - recall: 0.9903 - accuracy: 0.9910 - val_loss: 0.6914 - val_precision: 0.7617 - val_recall: 0.8305 - val_accuracy: 0.7853
# Epoch 8/200
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0483 - precision: 0.9903 - recall: 0.9958 - accuracy: 0.9930 - val_loss: 0.6944 - val_precision: 0.7538 - val_recall: 0.8305 - val_accuracy: 0.7797
# Epoch 9/200
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0470 - precision: 0.9930 - recall: 0.9903 - accuracy: 0.9917 - val_loss: 0.6844 - val_precision: 0.7634 - val_recall: 0.8023 - val_accuracy: 0.7768
# Epoch 10/200
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0478 - precision: 0.9931 - recall: 0.9972 - accuracy: 0.9951 - val_loss: 0.6943 - val_precision: 0.7500 - val_recall: 0.8305 - val_accuracy: 0.7768
# Epoch 11/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0475 - precision: 0.9930 - recall: 0.9930 - accuracy: 0.9930 - val_loss: 0.6903 - val_precision: 0.7565 - val_recall: 0.8249 - val_accuracy: 0.7797
# Epoch 12/200
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0499 - precision: 0.9930 - recall: 0.9903 - accuracy: 0.9917 - val_loss: 0.6855 - val_precision: 0.7553 - val_recall: 0.8023 - val_accuracy: 0.7712
# Epoch 13/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0438 - precision: 0.9972 - recall: 0.9972 - accuracy: 0.9972 - val_loss: 0.6958 - val_precision: 0.7604 - val_recall: 0.8249 - val_accuracy: 0.7825
# Epoch 14/200
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0446 - precision: 0.9986 - recall: 0.9889 - accuracy: 0.9937 - val_loss: 0.6986 - val_precision: 0.7526 - val_recall: 0.8249 - val_accuracy: 0.7768
# Epoch 15/200
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0435 - precision: 0.9972 - recall: 0.9972 - accuracy: 0.9972 - val_loss: 0.6989 - val_precision: 0.7565 - val_recall: 0.8249 - val_accuracy: 0.7797
# Epoch 16/200
# 3/3 [==============================] - 0s 35ms/step - loss: 0.
200
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0271 - precision: 0.9958 - recall: 1.0000 - accuracy: 0.9979 - val_loss: 0.7823 - val_precision: 0.7566 - val_recall: 0.8079 - val_accuracy: 0.7740
# Epoch 144/200
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0275 - precision: 1.0000 - recall: 0.9972 - accuracy: 0.9986 - val_loss: 0.7738 - val_precision: 0.7632 - val_recall: 0.8192 - val_accuracy: 0.7825
# Epoch 145/200
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0252 - precision: 1.0000 - recall: 1.0000 - accuracy: 1.0000 - val_loss: 0.7653 - val_precision: 0.7604 - val_recall: 0.8249 - val_accuracy: 0.7825
# Epoch 146/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0253 - precision: 1.0000 - recall: 0.9972 - accuracy: 0.9986 - val_loss: 0.7801 - val_precision: 0.7513 - val_recall: 0.8362 - val_accuracy: 0.7797
# Epoch 147/200
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0283 - precision: 0.9972 - recall: 0.9986 - accuracy: 0.9979 - val_loss: 0.7768 - val_precision: 0.7579 - val_recall: 0.8136 - val_accuracy: 0.7768
# Epoch 148/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0294 - precision: 0.9972 - recall: 0.9986 - accuracy: 0.9979 - val_loss: 0.7715 - val_precision: 0.7579 - val_recall: 0.8136 - val_accuracy: 0.7768
# Epoch 149/200
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0269 - precision: 0.9972 - recall: 0.9986 - accuracy: 0.9979 - val_loss: 0.7804 - val_precision: 0.7592 - val_recall: 0.8192 - val_accuracy: 0.7797
# Epoch 150/200
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0261 - precision: 0.9958 - recall: 0.9972 - accuracy: 0.9965 - val_loss: 0.7840 - val_precision: 0.7644 - val_recall: 0.8249 - val_accuracy: 0.7853
# Epoch 151/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0263 - precision: 1.0000 - recall: 0.9958 - accuracy: 0.9979 - val_loss: 0.7797 - val_precision: 0.7672 - val_recall: 0.8192 - val_accuracy: 0.7853
# Epoch 152/200
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0262 - precision: 1.0000 - recall: 1.0000 - accuracy: 1.0000 - val_loss: 0.7933 - val_precision: 0.7604 - val_recall: 0.8249 - val_accuracy: 0.7825
# Epoch 153/200
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0237 - precision: 0.9972 - recall: 1.0000 - accuracy: 0.9986 - val_loss: 0.7847 - val_precision: 0.7701 - val_recall: 0.8136 - val_accuracy: 0.7853
# Epoch 154/200
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0254 - precision: 0.9986 - recall: 0.9986 - accuracy: 0.9986 - val_loss: 0.7824 - val_precision: 0.7672 - val_recall: 0.8192 - val_accuracy: 0.7853
# Epoch 155/200
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0258 - precision: 0.9986 - recall: 1.0000 - accuracy: 0.9993 - val_loss: 0.8136 - val_precision: 0.7525 - val_recall: 0.8418 - val_accuracy: 0.7825
# Epoch 156/200
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0266 - precision: 0.9986 - recall: 1.0000 - accuracy: 0.9993 - val_loss: 0.7860 - val_precision: 0.7592 - val_recall: 0.8192 - val_accuracy: 0.7797
# Epoch 157/200
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0241 - precision: 1.0000 - recall: 0.9986 - accuracy: 0.9993 - val_loss: 0.7879 - val_precision: 0.7604 - val_recall: 0.8249 - val_accuracy: 0.7825
# Epoch 158/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0258 - precision: 0.9958 - recall: 0.9972 - accuracy: 0.9965 - val_loss: 0.8093 - val_precision: 0.7590 - val_recall: 0.8362 - val_accuracy: 0.7853
# Epoch 159/200
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0240 - precision: 0.9986 - recall: 1.0000 - accuracy: 0.9993 - val_loss: 0.7951 - val_precision: 0.7592 - val_recall: 0.8192 - val_accuracy: 0.7797
# Epoch 160/200
# 3/3 [==============================] - 0s 39ms/step - loss: 0.
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0225 - precision: 0.9986 - recall: 1.0000 - accuracy: 0.9993 - val_loss: 0.7978 - val_precision: 0.7647 - val_recall: 0.8079 - val_accuracy: 0.7797
# Epoch 194/200
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0248 - precision: 0.9986 - recall: 0.9972 - accuracy: 0.9979 - val_loss: 0.8162 - val_precision: 0.7538 - val_recall: 0.8305 - val_accuracy: 0.7797
# Epoch 195/200
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0229 - precision: 0.9972 - recall: 1.0000 - accuracy: 0.9986 - val_loss: 0.8049 - val_precision: 0.7526 - val_recall: 0.8249 - val_accuracy: 0.7768
# Epoch 196/200
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0230 - precision: 1.0000 - recall: 0.9958 - accuracy: 0.9979 - val_loss: 0.7996 - val_precision: 0.7619 - val_recall: 0.8136 - val_accuracy: 0.7797
# Epoch 197/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0247 - precision: 0.9972 - recall: 0.9986 - accuracy: 0.9979 - val_loss: 0.8233 - val_precision: 0.7526 - val_recall: 0.8249 - val_accuracy: 0.7768
# Epoch 198/200
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0232 - precision: 0.9986 - recall: 0.9986 - accuracy: 0.9986 - val_loss: 0.7946 - val_precision: 0.7632 - val_recall: 0.8192 - val_accuracy: 0.7825
# Epoch 199/200
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0256 - precision: 0.9958 - recall: 0.9986 - accuracy: 0.9972 - val_loss: 0.8227 - val_precision: 0.7563 - val_recall: 0.8418 - val_accuracy: 0.7853
# Epoch 200/200
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0204 - precision: 0.9972 - recall: 1.0000 - accuracy: 0.9986 - val_loss: 0.8013 - val_precision: 0.7634 - val_recall: 0.8023 - val_accuracy: 0.7768

# %%
train_predictions = model.predict(X_train)
test_predictions = model.predict(X_test)
# Out:
# 45/45 [==============================] - 0s 3ms/step
# 12/12 [==============================] - 0s 5ms/step

# %%
print("train set")
print("precision score: ", precision_score(y_train, (train_predictions > 0.5).astype(int)))
print("recall score: ", recall_score(y_train, (train_predictions > 0.5).astype(int)))
print("test set")
print("precision score: ", precision_score(y_test, (test_predictions > 0.5).astype(int)))
print("recall score: ", recall_score(y_test, (test_predictions > 0.5).astype(int)))
# Out:
# train set
# precision score:  1.0
# recall score:  1.0
# test set
# precision score:  0.7634408602150538
# recall score:  0.8022598870056498

# %%
# Displaying the images with predictions


def show_image(index):
    rgb_image = np.reshape(X_test[index], (28, 28, 3))
    plt.imshow(rgb_image)
    plt.axis("off")
    plt.show()

    class_label_widget.value = f"Class (0 or 1): {y_test[index]}"
    predicted_value_widget.value = f"Predicted Value: {test_predictions[index]}"
    predicted_class_widget.value = f"Predicted Class: {0 if test_predictions[index] < 0.5 else 1}"


class_label_widget = widgets.Label(value=f"Actual Class (0 or 1): {-1}")

predicted_value_widget = widgets.Label(value=f"Predicted Value: {-1}")

predicted_class_widget = widgets.Label(value=f'Predicted Class: {-1}')

image_widget = widgets.interactive(
    show_image, index=widgets.IntSlider(min=0, max=len(X_test) - 1, step=1, value=0)
)
display(image_widget, class_label_widget, predicted_value_widget, predicted_class_widget)
# Out:
# interactive(children=(IntSlider(value=0, description='index', max=2146), Output()), _dom_classes=('widget-inte…
# Label(value='Class (0 or 1): 1.0')
# Label(value='Predicted Value: [0.9999641]')
# Label(value='Predicted Class: 1')
